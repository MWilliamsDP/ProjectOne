# %%
import requests
import json
from pprint import pprint

# %%
url = 'https://www.balldontlie.io/api/v1/games'

# %%
response = requests.get(url).json()

# %%
pprint (response)
# Out:
# {'data': [{'date': '2019-01-30T00:00:00.000Z',
#            'home_team': {'abbreviation': 'BOS',
#                          'city': 'Boston',
#                          'conference': 'East',
#                          'division': 'Atlantic',
#                          'full_name': 'Boston Celtics',
#                          'id': 2,
#                          'name': 'Celtics'},
#            'home_team_score': 126,
#            'id': 47179,
#            'period': 4,
#            'postseason': False,
#            'season': 2018,
#            'status': 'Final',
#            'time': ' ',
#            'visitor_team': {'abbreviation': 'CHA',
#                             'city': 'Charlotte',
#                             'conference': 'East',
#                             'division': 'Southeast',
#                             'full_name': 'Charlotte Hornets',
#                             'id': 4,
#                             'name': 'Hornets'},
#            'visitor_team_score': 94},
# ...
